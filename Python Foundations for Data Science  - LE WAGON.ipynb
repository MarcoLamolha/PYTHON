# %% [markdown]
# # Python Foundations for Data Science 🤓

# %% [markdown]
# # Agenda for our workshop ⏰
#
# ### Basics first 🐣 Python Data Types (40 min)
# *  Strings
# *  Practice Round ✍️
# *  Integers and Floats
# *  Practice Round ✍️
#
# ### Data Analytics - Reading Data in Python 🧮(30 min)
# *  Tools we will use
# *  Importing data from CSV
# *  Previewing the DataFrame
# *  Practice Round ✍️
#
# ### Data Analytics - Our first analysis 🔍(50 min)
# *  Boolean analysis
# *  Our first analysis - let's check out the largest countries
# *  Combining data points for more insight
# *  Practice Round ✍️
# *  Data visualization

# %% [markdown]
# ### Welcome to the Jupyter Notebook! How to use this file? 🤔
#
# * Type inside the empty cells to write code. These empty cells will have a `In [ ]:` prefix before
# * Press the `return/enter ⏎` key to add a new line inside the cell
# * To display your results use the Python built in `print(STUFF_YOU_WANT_TO_PRINT)` method or simply put the stuff you want to print as the last line inside the cell. The result of the last line will appear as the `Out[]:` or the output of the cell :)
# * Press `shift` + `return/enter ⏎` to run your code 🤓 this will run the code inside your currently selected cell and print anything inside `print()` method and the last line of your cell
# * To add a new cell, select any cell and press the `b` key (make sure you are not just typing the letter `b` in the cell). This will add a new cell below
# * To delete a cell, double press the `d` key (make sure you are not just typing the letter `d` in the cell)
#
# #### Try to run the code below! 😃

# %%
print("Welcome to the Python workshop of Le Wagon!")
print("Are you ready to do your first data analysis?")
"Yes we are! 🚀"
# Out:
# Welcome to the Python workshop of Le Wagon!
# Are you ready to do your first data analysis?
# 'Yes we are! 🚀'

# %% [markdown]
# ## Python Basics ⚙️

# %% [markdown]
#     Everything in Python is an object. Objects have attributes and methods.
# Real life example: a car as an object, has attributes such as color, make, year of manufacture, transmission mode etc., and methods such as accelerating, reverse, braking.

# %% [markdown]
# ### Python Data Types and Variables 🧱
# - Strings
# - Integers
# - Floats
# - Booleans & Logicals
# - Variables
# - Lists & Dictionaries*
#
# *Only FYI

# %% [markdown]
# ### STRINGS   str() 📝
# To represent a text and defined with "double" or 'single' quotes
#
#     "Python for Beginners"
#     'Python for Beginners'
#     '2019'

# %% [markdown]
# #### Built-in Methods for Strings
#     type("python")
#     int('2019')
#     len("python")
#     'python'.capitalize()
#     "python is fun".count('n')
#     "PYTHON".lower()
#     'python'.index('o')

# %% [markdown]
# ###  🚀 Try out built-in methods for `strings` !
#
# How? Type in a line of code on the empty line below and press `Shift` + `enter/return ⏎` keys to run it

# %%
a = type("python")
b = int('2019')
c = len("python")
d = 'python'.capitalize()
e = "python is fun".count('n')
f = "PYTHON".lower()
g = 'python'.index('o')

print(a,b,c,d,e,f,g)
# Out:
# <class 'str'> 2019 6 Python 2 python 4

# %% [markdown]
# ### INTEGERS   int() 🔢
# To represent integers and can do standard arithmetics.
#
#     10
#     -24
#     2019

# %% [markdown]
# #### Built-in Methods for Integers
#     type(10)
#     abs(-24)
#     min(10, -24, 2019)
#     max(10, -24, 2019)
#     float(10)

# %% [markdown]
# #### Arithmetic Operators
#     1 + 2    => 3  (Addition)
#     1 - 2    => -1 (Subtraction)
#     2 * 4    => 8  (Multiplication)
#     5 / 2    => 2.5(Division)
#     5 // 2   => 2  (Floor division)
#     5 % 2    => 1  (Modulus)
#     2 ** 3   => 8  (Exponent)

# %% [markdown]
# ### FLOATS   float()
# To represent decimal numbers and can do standard arithmetics.
#
#     10.23132
#     -24.1
#     2019.0

# %% [markdown]
# #### Built-in Methods for Floats
#     all built-functions for integers
#     round(10.23132, 2)
#     import math # first import math package - a collection of advanced mathematical functions
#     math.floor(10.23132)
#     math.ceil(-24.1)
#     math.ceil(24.1)
#     math.factorial(5)

# %% [markdown]
# ###   🚀Try out built-in methods for `integers` and `floats` below!
#
# How? Type in a line of code on the empty line below and press `Shift` + `enter/return ⏎` keys to run it

# %%
a = round(10.23132, 2)
import math # first import math package - a collection of advanced mathematical functions
c = math.floor(10.23132)   
d = math.ceil(-24.1)
e = math.ceil(24.1)
f = math.factorial(5)


print(a,c,d,e,f)
# Out:
# 10.23 10 -24 25 120

# %% [markdown]
# ### BOOLEANS & LOGICALS   bool() 🔀
# Booleans represent something that is True or False
#
#     True
#     False
#
# Comparison Operators always yield Boolean values
#
#      ==       # different from assignment operator '='
#      !=
#      > or >=
#      < or <=
#
# Logicals include:
#
#     or
#     and
#     not

# %% [markdown]
# ### VARIABLES 📦
# - Allows you to store values to reuse later
# - You assign a value to a variable
# - Variables can be overwritten and incremented
# - By convention, variable names should be in snake_case
#
# Variable assignment statement - *putting things in a box*
#
#     putting the `string` "John" in the box `first_name`
#
#         first_name = "John"
#
#     putting the `integer` 29 in the box `age`
#
#         age = 29
#
#
# Variable reading - *opening the box to see what is inside*
#
#     print(age)
#     print(first_name)

# %% [markdown]
# ###  🚀Try out `booleans` and `variables`
#
# How? Type in a line of code on the empty line below and press `Shift` + `enter/return ⏎` keys to run it.

# %%
a = "Pasta" == "Pasto"
print(a)
# Out:
# False

# %% [markdown]
# ### Practice! ✍️ Try out `strings`, `integers`, `floats`,  `booleans` and `variables` below!
#
# Some ideas:
# - Make two variables and check if they are equal (*pssst*, ==)
# - Make two variables - your first name and last name
# - Create your own full name out of first_name and last_name variables (make sure it’s always capitalized!)
# - Check the length of your full name
# - Make todays date out of a year, month and day variables 🤔
# - Create a variable with your age in years - now calculate your age in minutes (approximately)
# - A class of students got their exams graded 15, 12, 11, 16, 18. Calculate the grade average.
#
# How? Type in a line of code on the empty line below and press `Shift` + `enter/return ⏎` keys to run it.

# %%
a = "10/08/2022"

day = a[0:2]
print(day)
# Out:
# 10

# %% [markdown]
# # Data Science - Analysis 🧮

# %% [markdown]
# ### First of all - what are we using? 🔨

# %% [markdown]
# [Jupyter Notebook](https://jupyter.org) is an open-source web application which allows you to create and share documents with code, visualizations and narrative. Which is what we are doing right now!

# %% [markdown]
# [Numpy](https://www.numpy.org) fundamental package for scientific computing in Python.

# %% [markdown]
# [Pandas](https://pandas.pydata.org) is an open-source library providing easy to use data structuring and analytics for Python.

# %% [markdown]
# ### So this is how every Jupyter notebook starts...

# %%
import numpy as np
import pandas as pd
print("You are good to go!")
# Out:
# You are good to go!

# %% [markdown]
# ### Python and Pandas is great for reading data files, like CSV

# %%
file = "countries of the world.csv"
countries_data = pd.read_csv(file, decimal=",")
# no need to use print() when we want to see DataFrames, simply put what you want to see on the last line
countries_data
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0            647500                        48.0                          0.00
# 1             28748                       124.6                          1.26
# 2           2381740                        13.8                          0.04
# 3               199                       290.4                         58.29
# 4               468                       152.1                          0.00
# ..              ...                         ...                           ...
# 222            5860                       419.9                          0.00
# 223          266000                         1.0                          0.42
# 224          527970                        40.6                          0.36
# 225          752614                        15.3                          0.00
# 226          390580                        31.3                          0.00
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0            23.06                              163.07               700.0
# 1            -4.93                               21.52              4500.0
# 2            -0.39                               31.00              6000.0
# 3           -20.71                                9.27              8000.0
# 4             6.60                                4.05             19000.0
# ..             ...                                 ...                 ...
# 222           2.98                               19.62               800.0
# 223            NaN                                 NaN                 NaN
# 224           0.00                               61.50               800.0
# 225           0.00                               88.29               800.0
# 226           0.00                               67.69              1900.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 0            36.0                3.2       12.13       0.22      87.65
# 1            86.5               71.2       21.09       4.42      74.49
# 2            70.0               78.1        3.22       0.25      96.53
# 3            97.0              259.5       10.00      15.00      75.00
# 4           100.0              497.2        2.22       0.00      97.78
# ..            ...                ...         ...        ...        ...
# 222           NaN              145.2       16.90      18.97      64.13
# 223           NaN                NaN        0.02       0.00      99.98
# 224          50.2               37.2        2.78       0.24      96.98
# 225          80.6                8.2        7.08       0.03      92.90
# 226          90.7               26.8        8.32       0.34      91.34
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 0        1.0      46.60      20.34        0.380     0.240    0.380
# 1        3.0      15.11       5.22        0.232     0.188    0.579
# 2        1.0      17.14       4.61        0.101     0.600    0.298
# 3        2.0      22.46       3.27          NaN       NaN      NaN
# 4        3.0       8.71       6.25          NaN       NaN      NaN
# ..       ...        ...        ...          ...       ...      ...
# 222      3.0      31.67       3.92        0.090     0.280    0.630
# 223      1.0        NaN        NaN          NaN       NaN    0.400
# 224      1.0      42.89       8.30        0.135     0.472    0.393
# 225      2.0      41.00      19.93        0.220     0.290    0.489
# 226      2.0      28.01      21.84        0.179     0.243    0.579
#
# [227 rows x 20 columns]

# %% [markdown]
# ### We can then have a quick look at our `DataFrame` 🗺

# %% [markdown]
# We can run `countries_data.shape` to check how many rows and columns we have. The result will be printed as (rows, columns)

# %%
print("rows and columns -->", countries_data.shape)
# Out:
# rows and columns --> (227, 20)

# %% [markdown]
# We can run `countries_data.columns` to check all the columns that our DataFrame has

# %%
print("all column names -->", countries_data.columns)
# Out:
# all column names --> Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %% [markdown]
# We can run `countries_data.head(YOUR_NUMBER)` to check the first `YOUR_NUMBER` of records of the DataFrame

# %%
countries_data.head(5) # will show the first 5 records
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0          23.06                              163.07               700.0
# 1          -4.93                               21.52              4500.0
# 2          -0.39                               31.00              6000.0
# 3         -20.71                                9.27              8000.0
# 4           6.60                                4.05             19000.0
#
#    Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# 0          36.0                3.2       12.13       0.22      87.65      1.0
# 1          86.5               71.2       21.09       4.42      74.49      3.0
# 2          70.0               78.1        3.22       0.25      96.53      1.0
# 3          97.0              259.5       10.00      15.00      75.00      2.0
# 4         100.0              497.2        2.22       0.00      97.78      3.0
#
#    Birthrate  Deathrate  Agriculture  Industry  Service
# 0      46.60      20.34        0.380     0.240    0.380
# 1      15.11       5.22        0.232     0.188    0.579
# 2      17.14       4.61        0.101     0.600    0.298
# 3      22.46       3.27          NaN       NaN      NaN
# 4       8.71       6.25          NaN       NaN      NaN

# %% [markdown]
# We can run `countries_data.tail(YOUR_NUMBER)` to check the last `YOUR_NUMBER` records of the DataFrame

# %%
countries_data.tail(5) # will show the last 5 records
# Out:
#              Country                               Region  Population  \
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 222            5860                       419.9                          0.00
# 223          266000                         1.0                          0.42
# 224          527970                        40.6                          0.36
# 225          752614                        15.3                          0.00
# 226          390580                        31.3                          0.00
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 222           2.98                               19.62               800.0
# 223            NaN                                 NaN                 NaN
# 224           0.00                               61.50               800.0
# 225           0.00                               88.29               800.0
# 226           0.00                               67.69              1900.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 222           NaN              145.2       16.90      18.97      64.13
# 223           NaN                NaN        0.02       0.00      99.98
# 224          50.2               37.2        2.78       0.24      96.98
# 225          80.6                8.2        7.08       0.03      92.90
# 226          90.7               26.8        8.32       0.34      91.34
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 222      3.0      31.67       3.92        0.090     0.280    0.630
# 223      1.0        NaN        NaN          NaN       NaN    0.400
# 224      1.0      42.89       8.30        0.135     0.472    0.393
# 225      2.0      41.00      19.93        0.220     0.290    0.489
# 226      2.0      28.01      21.84        0.179     0.243    0.579

# %% [markdown]
# We can run `countries_data[COLUMN_NAME]` to see only the values of `COLUMN_NAME`

# %%
countries_data["Population"]
# Out:
# 0      31056997
# 1       3581655
# 2      32930091
# 3         57794
# 4         71201
#          ...
# 222     2460492
# 223      273008
# 224    21456188
# 225    11502010
# 226    12236805
# Name: Population, Length: 227, dtype: int64

# %% [markdown]
# We can run `countries_data[[COLUMN_NAME_1, COLUMN_NAME_2,...etc]]` to see a few values together using the double square bracket notation

# %%
countries_data[["Country", "Population"]]
# Out:
#              Country  Population
# 0       Afghanistan     31056997
# 1           Albania      3581655
# 2           Algeria     32930091
# 3    American Samoa        57794
# 4           Andorra        71201
# ..               ...         ...
# 222       West Bank      2460492
# 223  Western Sahara       273008
# 224           Yemen     21456188
# 225          Zambia     11502010
# 226        Zimbabwe     12236805
#
# [227 rows x 2 columns]

# %% [markdown]
# #### Bonus: What if you want to show data for just one country?

# %%
countries_data['Country'] = countries_data['Country'].map(str.strip) # Clean the text in Country column
countries_data.set_index('Country', inplace=True) # Set Country names as the unique index
countries_data
# Out:
#                                              Region  Population  \
# Country
# Afghanistan           ASIA (EX. NEAR EAST)             31056997
# Albania         EASTERN EUROPE                          3581655
# Algeria         NORTHERN AFRICA                        32930091
# American Samoa  OCEANIA                                   57794
# Andorra         WESTERN EUROPE                            71201
# ...                                             ...         ...
# West Bank       NEAR EAST                               2460492
# Western Sahara  NORTHERN AFRICA                          273008
# Yemen           NEAR EAST                              21456188
# Zambia          SUB-SAHARAN AFRICA                     11502010
# Zimbabwe        SUB-SAHARAN AFRICA                     12236805
#
#                 Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# Country
# Afghanistan             647500                        48.0
# Albania                  28748                       124.6
# Algeria                2381740                        13.8
# American Samoa             199                       290.4
# Andorra                    468                       152.1
# ...                        ...                         ...
# West Bank                 5860                       419.9
# Western Sahara          266000                         1.0
# Yemen                   527970                        40.6
# Zambia                  752614                        15.3
# Zimbabwe                390580                        31.3
#
#                 Coastline (coast/area ratio)  Net migration  \
# Country
# Afghanistan                             0.00          23.06
# Albania                                 1.26          -4.93
# Algeria                                 0.04          -0.39
# American Samoa                         58.29         -20.71
# Andorra                                 0.00           6.60
# ...                                      ...            ...
# West Bank                               0.00           2.98
# Western Sahara                          0.42            NaN
# Yemen                                   0.36           0.00
# Zambia                                  0.00           0.00
# Zimbabwe                                0.00           0.00
#
#                 Infant mortality (per 1000 births)  GDP ($ per capita)  \
# Country
# Afghanistan                                 163.07               700.0
# Albania                                      21.52              4500.0
# Algeria                                      31.00              6000.0
# American Samoa                                9.27              8000.0
# Andorra                                       4.05             19000.0
# ...                                            ...                 ...
# West Bank                                    19.62               800.0
# Western Sahara                                 NaN                 NaN
# Yemen                                        61.50               800.0
# Zambia                                       88.29               800.0
# Zimbabwe                                     67.69              1900.0
#
#                 Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  \
# Country
# Afghanistan             36.0                3.2       12.13       0.22
# Albania                 86.5               71.2       21.09       4.42
# Algeria                 70.0               78.1        3.22       0.25
# American Samoa          97.0              259.5       10.00      15.00
# Andorra                100.0              497.2        2.22       0.00
# ...                      ...                ...         ...        ...
# West Bank                NaN              145.2       16.90      18.97
# Western Sahara           NaN                NaN        0.02       0.00
# Yemen                   50.2               37.2        2.78       0.24
# Zambia                  80.6                8.2        7.08       0.03
# Zimbabwe                90.7               26.8        8.32       0.34
#
#                 Other (%)  Climate  Birthrate  Deathrate  Agriculture  \
# Country
# Afghanistan         87.65      1.0      46.60      20.34        0.380
# Albania             74.49      3.0      15.11       5.22        0.232
# Algeria             96.53      1.0      17.14       4.61        0.101
# American Samoa      75.00      2.0      22.46       3.27          NaN
# Andorra             97.78      3.0       8.71       6.25          NaN
# ...                   ...      ...        ...        ...          ...
# West Bank           64.13      3.0      31.67       3.92        0.090
# Western Sahara      99.98      1.0        NaN        NaN          NaN
# Yemen               96.98      1.0      42.89       8.30        0.135
# Zambia              92.90      2.0      41.00      19.93        0.220
# Zimbabwe            91.34      2.0      28.01      21.84        0.179
#
#                 Industry  Service
# Country
# Afghanistan        0.240    0.380
# Albania            0.188    0.579
# Algeria            0.600    0.298
# American Samoa       NaN      NaN
# Andorra              NaN      NaN
# ...                  ...      ...
# West Bank          0.280    0.630
# Western Sahara       NaN    0.400
# Yemen              0.472    0.393
# Zambia             0.290    0.489
# Zimbabwe           0.243    0.579
#
# [227 rows x 19 columns]

# %% [markdown]
# Now we can see instead of numbers, we have country names as our index
#
# ⚠️**Note** that when you do this you remove the `Country` column, and make it the index of the whole DataFrame instead (for example, `country_data['Country']` will not work any more)
#
# We can simply use `countries_data.loc['COUTRY_NAME']` syntax to get data for one country

# %%
countries_data.loc['Algeria']
# Out:
# Region                                NORTHERN AFRICA
# Population                                                       32930091
# Area (sq. mi.)                                                    2381740
# Pop. Density (per sq. mi.)                                           13.8
# Coastline (coast/area ratio)                                         0.04
# Net migration                                                       -0.39
# Infant mortality (per 1000 births)                                   31.0
# GDP ($ per capita)                                                 6000.0
# Literacy (%)                                                         70.0
# Phones (per 1000)                                                    78.1
# Arable (%)                                                           3.22
# Crops (%)                                                            0.25
# Other (%)                                                           96.53
# Climate                                                               1.0
# Birthrate                                                           17.14
# Deathrate                                                            4.61
# Agriculture                                                         0.101
# Industry                                                              0.6
# Service                                                             0.298
# Name: Algeria, dtype: object

# %% [markdown]
# ###  Your turn! 🚀Run the code above to import `numpy` and `pandas` and read the CSV to get `countrie_data`. No need to change anything there ;)
#
# #### Now play around with your `DataFrame` 🤓
#
# Some ideas:
# * check the amount of rows and columns in your DataFrame
# * check what are all the columns that you have
# * view only the "Climate" column of your DataFrame
# * view the first 10 rows of your DataFrame
# * view the last 10 rows of your DataFrame, but only viewing the "Country", "Population" and "Climate" 🤔
#
# How? Type in your code on the empty line below and press `Shift` + `enter/return ⏎` keys to run it

# %%
countries_data[["Population","Climate"]].tail(10)
# Out:
#                    Population  Climate
# Country
# Vanuatu                208869      2.0
# Venezuela            25730435      2.0
# Vietnam              84402966      2.0
# Virgin Islands         108605      2.0
# Wallis and Futuna       16025      2.0
# West Bank             2460492      3.0
# Western Sahara         273008      1.0
# Yemen                21456188      1.0
# Zambia               11502010      2.0
# Zimbabwe             12236805      2.0

# %% [markdown]
# ## Now let's do some data analytics! 🔍

# %% [markdown]
# #### Let's say we want to see countries with over 50,000,000 people. We want to create a `boolean` - `True` or `False` - with this condition

# %%
large_population = countries_data["Population"] > 50_000_000
large_population
# Out:
# Country
# Afghanistan       False
# Albania           False
# Algeria           False
# American Samoa    False
# Andorra           False
#                   ...
# West Bank         False
# Western Sahara    False
# Yemen             False
# Zambia            False
# Zimbabwe          False
# Name: Population, Length: 227, dtype: bool

# %% [markdown]
# #### We can see that `large_population` is now a list of `True` and `False` values, matching our countries DataFrame 🧐

# %% [markdown]
# #### Now we can apply this condition to our `countries_data` using the square brackets `[condition]`, same syntax as we used for checking columns

# %%
large_countries = countries_data[large_population]
large_countries
# Out:
#                                                Region  Population  \
# Country
# Bangladesh              ASIA (EX. NEAR EAST)            147365352
# Brazil                        LATIN AMER. & CARIB       188078227
# China                   ASIA (EX. NEAR EAST)           1313973713
# Congo, Dem. Rep.  SUB-SAHARAN AFRICA                     62660551
# Egypt             NORTHERN AFRICA                        78887007
# Ethiopia          SUB-SAHARAN AFRICA                     74777981
# France            WESTERN EUROPE                         60876136
# Germany           WESTERN EUROPE                         82422299
# India                   ASIA (EX. NEAR EAST)           1095351995
# Indonesia               ASIA (EX. NEAR EAST)            245452739
# Iran                    ASIA (EX. NEAR EAST)             68688433
# Italy             WESTERN EUROPE                         58133509
# Japan                   ASIA (EX. NEAR EAST)            127463611
# Mexico                        LATIN AMER. & CARIB       107449525
# Nigeria           SUB-SAHARAN AFRICA                    131859731
# Pakistan                ASIA (EX. NEAR EAST)            165803560
# Philippines             ASIA (EX. NEAR EAST)             89468677
# Russia                           C.W. OF IND. STATES    142893540
# Thailand                ASIA (EX. NEAR EAST)             64631595
# Turkey            NEAR EAST                              70413958
# United Kingdom    WESTERN EUROPE                         60609153
# United States     NORTHERN AMERICA                      298444215
# Vietnam                 ASIA (EX. NEAR EAST)             84402966
#
#                   Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# Country
# Bangladesh                144000                      1023.4
# Brazil                   8511965                        22.1
# China                    9596960                       136.9
# Congo, Dem. Rep.         2345410                        26.7
# Egypt                    1001450                        78.8
# Ethiopia                 1127127                        66.3
# France                    547030                       111.3
# Germany                   357021                       230.9
# India                    3287590                       333.2
# Indonesia                1919440                       127.9
# Iran                     1648000                        41.7
# Italy                     301230                       193.0
# Japan                     377835                       337.4
# Mexico                   1972550                        54.5
# Nigeria                   923768                       142.7
# Pakistan                  803940                       206.2
# Philippines               300000                       298.2
# Russia                  17075200                         8.4
# Thailand                  514000                       125.7
# Turkey                    780580                        90.2
# United Kingdom            244820                       247.6
# United States            9631420                        31.0
# Vietnam                   329560                       256.1
#
# Indonesia             81.45      2.0      20.34       6.25        0.134
# Iran                  89.89      1.0      17.00       5.55        0.116
# Italy                 62.68      NaN       8.72      10.40        0.021
# Japan                 86.85      3.0       9.37       9.16        0.017
# Mexico                85.70      1.5      20.69       4.74        0.038
# Nigeria               65.75      1.5      40.43      16.94        0.269
# Pakistan              71.26      1.0      29.74       8.23        0.216
# Philippines           64.28      2.0      24.89       5.41        0.144
# Russia                92.56      NaN       9.95      14.65        0.054
# Thailand              64.18      2.0      13.87       7.04        0.099
# Turkey                65.76      3.0      16.62       5.97        0.117
# United Kingdom        76.33      3.0      10.71      10.13        0.005
# United States         80.65      3.0      14.14       8.26        0.010
# Vietnam               74.08      2.0      16.86       6.22        0.209
#
#                   Industry  Service
# Country
# Bangladesh           0.198    0.603
# Brazil               0.400    0.516
# China                0.473    0.403
# Congo, Dem. Rep.     0.110    0.340
# Egypt                0.357    0.493
# Ethiopia             0.099    0.426
# France               0.214    0.764
# Germany              0.296    0.695
# India                0.276    0.538
# Indonesia            0.458    0.408
# Iran                 0.424    0.460
# Italy                0.291    0.688
# Japan                0.258    0.725
# Mexico               0.259    0.702
# Nigeria              0.487    0.244
# Pakistan             0.251    0.533
# Philippines          0.326    0.530
# Russia               0.371    0.575
# Thailand             0.441    0.460
# Turkey               0.298    0.585
# United Kingdom       0.237    0.758
# United States        0.204    0.787
# Vietnam              0.410    0.381

# %% [markdown]
# #### Boom 💥we have our first data analytics solution!

# %% [markdown]
# We can also sort our large_countries by Population, having largest first, using the syntax of `large_countries.sort_values("COLUMN_TO_SORT_BY", ascending=False)`, like below

# %%
large_countries.sort_values("Population", ascending=False).head(5) # change False to True if you wan't smallest countries first :)
# Out:
#                                             Region  Population  \
# Country
# China                ASIA (EX. NEAR EAST)           1313973713
# India                ASIA (EX. NEAR EAST)           1095351995
# United States  NORTHERN AMERICA                      298444215
# Indonesia            ASIA (EX. NEAR EAST)            245452739
# Brazil                     LATIN AMER. & CARIB       188078227
#
#                Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# Country
# China                 9596960                       136.9
# India                 3287590                       333.2
# United States         9631420                        31.0
# Indonesia             1919440                       127.9
# Brazil                8511965                        22.1
#
#                Coastline (coast/area ratio)  Net migration  \
# Country
# China                                  0.15          -0.40
# India                                  0.21          -0.07
# United States                          0.21           3.41
# Indonesia                              2.85           0.00
# Brazil                                 0.09          -0.03
#
#                Infant mortality (per 1000 births)  GDP ($ per capita)  \
# Country
# China                                       24.18              5000.0
# India                                       56.29              2900.0
# United States                                6.50             37800.0
# Indonesia                                   35.60              3200.0
# Brazil                                      29.61              7600.0
#
#                Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  \
# Country
# China                  90.9              266.7       15.40       1.25
# India                  59.5               45.4       54.40       2.74
# United States          97.0              898.0       19.13       0.22
# Indonesia              87.9               52.0       11.32       7.23
# Brazil                 86.4              225.3        6.96       0.90
#
#                Other (%)  Climate  Birthrate  Deathrate  Agriculture  \
# Country
# China              83.35      1.5      13.25       6.97        0.125
# India              42.86      2.5      22.01       8.18        0.186
# United States      80.65      3.0      14.14       8.26        0.010
# Indonesia          81.45      2.0      20.34       6.25        0.134
# Brazil             92.15      2.0      16.56       6.17        0.084
#
#                Industry  Service
# Country
# China             0.473    0.403
# India             0.276    0.538
# United States     0.204    0.787
# Indonesia         0.458    0.408
# Brazil            0.400    0.516

# %% [markdown]
# #### We can also combine data points! Let's see which of our large countries have the biggest Service industry 🤔

# %%
large_service_countries = large_countries.sort_values("Service", ascending=False)
large_service_countries
# Out:
#                                                Region  Population  \
# Country
# United States     NORTHERN AMERICA                      298444215
# France            WESTERN EUROPE                         60876136
# United Kingdom    WESTERN EUROPE                         60609153
# Japan                   ASIA (EX. NEAR EAST)            127463611
# Mexico                        LATIN AMER. & CARIB       107449525
# Germany           WESTERN EUROPE                         82422299
# Italy             WESTERN EUROPE                         58133509
# Bangladesh              ASIA (EX. NEAR EAST)            147365352
# Turkey            NEAR EAST                              70413958
# Russia                           C.W. OF IND. STATES    142893540
# India                   ASIA (EX. NEAR EAST)           1095351995
# Pakistan                ASIA (EX. NEAR EAST)            165803560
# Philippines             ASIA (EX. NEAR EAST)             89468677
# Brazil                        LATIN AMER. & CARIB       188078227
# Egypt             NORTHERN AFRICA                        78887007
# Iran                    ASIA (EX. NEAR EAST)             68688433
# Thailand                ASIA (EX. NEAR EAST)             64631595
# Ethiopia          SUB-SAHARAN AFRICA                     74777981
# Indonesia               ASIA (EX. NEAR EAST)            245452739
# China                   ASIA (EX. NEAR EAST)           1313973713
# Vietnam                 ASIA (EX. NEAR EAST)             84402966
# Congo, Dem. Rep.  SUB-SAHARAN AFRICA                     62660551
# Nigeria           SUB-SAHARAN AFRICA                    131859731
#
#                   Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# Country
# United States            9631420                        31.0
# France                    547030                       111.3
# United Kingdom            244820                       247.6
# Japan                     377835                       337.4
# Mexico                   1972550                        54.5
# Germany                   357021                       230.9
# Italy                     301230                       193.0
# Bangladesh                144000                      1023.4
# Turkey                    780580                        90.2
# Russia                  17075200                         8.4
# India                    3287590                       333.2
# Pakistan                  803940                       206.2
# Philippines               300000                       298.2
# Brazil                   8511965                        22.1
# Egypt                    1001450                        78.8
# Iran                     1648000                        41.7
# Thailand                  514000                       125.7
# Ethiopia                 1127127                        66.3
# Indonesia                1919440                       127.9
# China                    9596960                       136.9
# Vietnam                   329560                       256.1
# Congo, Dem. Rep.         2345410                        26.7
# Nigeria                   923768                       142.7
#
#                   Coastline (coast/area ratio)  Net migration  \
# Country
# United States                             0.21           3.41
# France                                    0.63           0.66
# United Kingdom                            5.08           2.19
# Japan                                     7.87           0.00
# Mexico                                    0.47          -4.87
# Germany                                   0.67           2.18
# Italy                                     2.52           2.07
# Bangladesh                                0.40          -0.71
# Turkey                                    0.92           0.00
# Russia                                    0.22           1.02
# India                                     0.21          -0.07
# Pakistan                                  0.13          -2.77
# Philippines                              12.10          -1.50
# Brazil                                    0.09          -0.03
# Egypt                                     0.24          -0.22
# Iran                                      0.15          -0.84
# Thailand                                  0.63           0.00
# Ethiopia                                  0.00           0.00
# Indonesia                                 2.85           0.00
# China                                     0.15          -0.40
# Vietnam                                   1.05          -0.45
# Congo, Dem. Rep.                          0.00           0.00
# Nigeria                                   0.09           0.26
#
#                   Infant mortality (per 1000 births)  GDP ($ per capita)  \
# Country
# Bangladesh           0.198    0.603
# Turkey               0.298    0.585
# Russia               0.371    0.575
# India                0.276    0.538
# Pakistan             0.251    0.533
# Philippines          0.326    0.530
# Brazil               0.400    0.516
# Egypt                0.357    0.493
# Iran                 0.424    0.460
# Thailand             0.441    0.460
# Ethiopia             0.099    0.426
# Indonesia            0.458    0.408
# China                0.473    0.403
# Vietnam              0.410    0.381
# Congo, Dem. Rep.     0.110    0.340
# Nigeria              0.487    0.244

# %% [markdown]
# Let's make our view a little cleaner - I only want to see the Country, Population and the ratio of Service industry. We can use the `large_service_countries[[COLUMN_NAME_1, COLUMN_NAME_2,...etc]]` syntax for that 🔍

# %%
large_service_countries[["Population", "Service"]].head(5)
# Out:
#                 Population  Service
# Country
# United States    298444215    0.787
# France            60876136    0.764
# United Kingdom    60609153    0.758
# Japan            127463611    0.725
# Mexico           107449525    0.702

# %% [markdown]
# ###  Your turn! 🚀 Explore your `DataFrame` and run some analysis 🤓
#
# Some ideas:
# * check which countries have the warmest climate ☀️
# * let's check the tiny countries! make a variable to store countries with Population < 3_000_000
# * Beach life! 😎check the countries with longest Coastline. Remember to type the full column name!
# * Are these coastal countries always online? 📱Let's sort them by amount of Phone usage. Again, check the full column name!
# #### ...and anything else you want to analyze! 🚀
#
# How? Type in your code on the empty line below and press `Shift` + `enter/return ⏎` keys to run it

# %% [markdown]
# ## Finally, let's make our findings visual 🎨

# %% [markdown]
# Once again, we already have Python libraries available for us with all we need.
#
# We will be using [matplotlib](https://matplotlib.org/) - a very popular data visualization library for Python.

# %%
# %matplotlib inline
import matplotlib # same as with pandas and numpy, we need to first import the library

# %% [markdown]
# Let's start by creating our first [plot](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html) out of our `large_service_countries` data

# %%
large_service_countries.plot()
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# 😰 Seems quite messy...
#
# Let's use the documentation of [DataFrame.plot](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html) and [matplotlib](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html?highlight=plot#matplotlib.pyplot.plot) to see how we can clean up our plot.

# %% [markdown]
# #### First of all, let's reduce the amount of data points we are trying to display

# %%
large_service_countries.head().plot(y='Service')
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# #### What is this strange zig-zag? Our horizontal axis (or the x-axis)! 💡

# %%
large_service_countries.head().plot(y='Service')
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# #### This line chart is not very fitting... let's see that other [kinds](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html) are available to us

# %%
large_service_countries.head().plot(kind='bar', y='Service')
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# #### Already much better! Now let's make it more interesting 🤓

# %%
large_service_countries.plot(
kind='bar',
y=['Service', 'Industry', 'Agriculture'],
stacked=True,
color=['#809BCE', '#B8E0D2', '#EAC4D5'],
figsize=(8, 6)).legend(loc='lower left')

# %% [markdown]
# ###  Your turn! 🚀 Visualize the `DataFrame` you've made in the previous challenges or make new ones 📊
#
# Remember to use online resources to see what are the different attributes you can play with:
#
# * Matplotlib documentation on [plot attributes](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html?highlight=plot#matplotlib.pyplot.plot)
# * Pandas documentation on the [DataFrame.plot() function we are using](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html)
# * 👉 [This neat article](http://queirozf.com/entries/pandas-dataframe-plot-examples-with-matplotlib-pyplot) with a bit more visual support
